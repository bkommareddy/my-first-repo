# %% [markdown]
# Hardware consists of the tangible parts of a computer that you can physically handle, whereas software includes the programs and instructions that operate on the hardware and control its functions.
